# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
for i in range(27):
  file = pd.read_csv('/content/drive/My Drive/clash/battle_data_'+str(i+10)+'.csv')
  df = pd.concat([df,file])

# %%
df = df.loc[df['type'] == "PvP"]

# %%
df
# Out:
#       type                                     gameMode  crowns1  \
# 0      PvP  {'id': 72000044, 'name': 'Ladder_GoldRush'}      1.0
# 1      PvP  {'id': 72000044, 'name': 'Ladder_GoldRush'}      1.0
# 2      PvP  {'id': 72000044, 'name': 'Ladder_GoldRush'}      2.0
# 3      PvP  {'id': 72000044, 'name': 'Ladder_GoldRush'}      1.0
# 4      PvP  {'id': 72000044, 'name': 'Ladder_GoldRush'}      1.0
# ...    ...                                          ...      ...
# 29972  PvP           {'id': 72000006, 'name': 'Ladder'}      0.0
# 29973  PvP           {'id': 72000006, 'name': 'Ladder'}      1.0
# 29976  PvP  {'id': 72000044, 'name': 'Ladder_GoldRush'}      1.0
# 29977  PvP  {'id': 72000044, 'name': 'Ladder_GoldRush'}      2.0
# 29980  PvP           {'id': 72000006, 'name': 'Ladder'}      0.0
#
#                                                   cards1  startingTrophies2  \
# 0      [{'name': 'Knight', 'id': 26000000, 'level': 1...             5854.0
# ...

# %%
df.to_csv('/content/drive/My Drive/clash/cleaned_clash_data_1.csv', index=False)
